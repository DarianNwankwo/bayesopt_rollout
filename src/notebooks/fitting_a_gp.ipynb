# %%
using GaussianDistributions
using CovarianceFunctions
using LinearAlgebra
using Plots

# %% [markdown]
# Suppose that we are given a dataset $D = \{(\textbf{x}_1, y_1), ... , (\textbf{x}_n, y_n)\}$ consisting of three
# observations, and we wish now to only consider functions that pass through these two data points exactly.
# Here, our objective function is
# $$\begin{aligned}
# -sin(3x) -x^2 + .7x
# \end{aligned}$$
# and our samples are likely to be tainted by gaussian noise. We define our function as follows, along with 3 samples $\in [-1, 2]$.

# %%
noise = .1

function f(x; σnoise=noise)
    return -sin(3*x) - x^2 + .7x + σnoise*randn()
end

sample_noise = 0.0
X_init = [-.9, 0.0]
Y_init = f.(X_init, σnoise=sample_noise)
# Out:
# 2-element Array{Float64,1}:
#  -1.0126201197661704
#   0.0

# %% [markdown]
# If we were to densely sample the function above, we'd see clearly that the function is smooth from $[-1, 2]$.

# %%
# Dense grid of points within bounds
bounds = -1:.05:2
X = collect(bounds)

# Noise-free objective function values at X
Y = f.(X, σnoise=0.)

# Plot noise-free optimization objective alongside noisy objective
scatter(X, f.(X), ms=2, label="Noisy Samples", color="orange")
plot!(X, Y, ls=:dash, lw=3, label="Noise-free Objective", color="black")
scatter!(X_init, Y_init, label="Initial Samples")

# %% [markdown]
# Now that we've sampled from our `unknown` process, we'd like to initialize our model and specify a covariance function for our Gaussian Process. For our covariance function, let's go with the Gaussian CovarianceFunctions. For our mean function, zero.

# %%
# Note that K == Σ, but we'll leverage Kernels.jl
ℓ = 1.
μ(x) = zero(x)
Σ(x, y) = CovarianceFunctions.Lengthscale(CovarianceFunctions.EQ(), ℓ)(x, y)
K(x, y) = exp(-norm(x - y)^2/(2ℓ^2))
x, y = rand(5), rand(5)
@assert K(x, y) ≈ Σ(x, y)

GP = Gaussian(μ, Σ)
# Out:
# Gaussian{typeof(μ),typeof(Σ)}(μ, Σ)

# %% [markdown]
# Once we've initialized our model, the next natural step is to condition our GP on observations. Thanks to the expressivity of Julia and some syntactic sugar,
# our conditional GP in code resembles what one might see in math.

# %%
CGP = GP | (X_init, Y_init, sample_noise);
# Out:
# SingularException(1)
#
# Stacktrace:
#  [1] inv(::Diagonal{Float64,Array{Float64,1}}) at /Users/julia/buildbot/worker/package_macos64/build/usr/share/julia/stdlib/v1.5/LinearAlgebra/src/diagonal.jl:607
#  [2] inverse at /Users/jamosa/.julia/packages/LazyInverse/FqfYP/src/LazyInverse.jl:34 [inlined]
#  [3] factorize(::WoodburyIdentity.Woodbury{Float64,Diagonal{Float64,Array{Float64,1}},Adjoint{Float64,Array{Float64,2}},Diagonal{Bool,Array{Bool,1}},Array{Float64,2},Int64,Nothing}, ::Int64, ::Val{true}) at /Users/jamosa/.julia/packages/WoodburyIdentity/aNZId/src/WoodburyIdentity.jl:197
#  [4] factorize at /Users/jamosa/.julia/packages/WoodburyIdentity/aNZId/src/WoodburyIdentity.jl:193 [inlined] (repeats 2 times)
#  [5] conditional(::Gaussian{typeof(μ),typeof(Σ)}, ::Array{Float64,1}, ::Gaussian{Array{Float64,1},Diagonal{Float64,Array{Float64,1}}}; tol::Float64) at /Users/jamosa/.julia/packages/GaussianDistributions/AUZIQ/src/conditional.jl:76
#  [6] conditional at /Users/jamosa/.julia/packages/GaussianDistributions/AUZIQ/src/conditional.jl:70 [inlined]
#  [7] conditional at /Users/jamosa/.julia/packages/GaussianDistributions/AUZIQ/src/conditional.jl:11 [inlined]
#  [8] |(::Gaussian{typeof(μ),typeof(Σ)}, ::Tuple{Array{Float64,1},Array{Float64,1},Float64}) at /Users/jamosa/.julia/packages/GaussianDistributions/AUZIQ/src/conditional.jl:7
#  [9] top-level scope at In[5]:1
#  [10] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %% [markdown]
# Now that we've conditioned our GP on our observations, let's plot the mean and pointwise variance to get a visual representation of our newly learned distribution
# of functions.

# %%
μ̂ = mean(CGP)
σ̂ = std(CGP)
plot(X, μ̂.(X), ribbon=2σ̂.(X))
scatter!(X_init, Y_init, label="Initial Samples")
# Out:
# UndefVarError: CGP not defined
#
# Stacktrace:
#  [1] top-level scope at In[6]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %% [markdown]
# Observe the graphs side by side

# %%
# Plot noise-free optimization objective alongside noisy objective
scatter(X, f.(X), ms=2, label="Noisy Samples", color="orange")
plot!(X, Y, ls=:dash, lw=3, label="Noise-free Objective", color="black")
scatter!(X_init, Y_init, label="Initial Samples")
plot!(X, μ̂.(X), ribbon=2σ̂.(X))

# %%
sample(CGP)
# Out:
# UndefVarError: CGP not defined
#
# Stacktrace:
#  [1] top-level scope at In[8]:1
#  [2] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
# Out:
# -0.11679063335112594
